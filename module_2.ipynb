# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters

# %%
data=pd.read_csv("week2.csv")
data
# Out:
#      Unnamed: 0 Symbol Series        Date  Prev Close  Open Price  High Price  \
# 0             0    TCS     EQ  2017-05-15     2360.65     2375.10     2377.95
# 1             1    TCS     EQ  2017-05-16     2365.10     2380.00     2435.00
# 2             2    TCS     EQ  2017-05-17     2429.15     2433.50     2460.75
# 3             3    TCS     EQ  2017-05-18     2455.35     2450.00     2572.00
# 4             4    TCS     EQ  2017-05-19     2536.20     2536.20     2540.55
# ..          ...    ...    ...         ...         ...         ...         ...
# 489         493    TCS     EQ  2019-05-07     2157.85     2160.05     2184.35
# 490         494    TCS     EQ  2019-05-08     2151.95     2151.00     2168.00
# 491         495    TCS     EQ  2019-05-09     2152.85     2145.00     2184.10
# 492         496    TCS     EQ  2019-05-10     2172.55     2175.00     2192.00
# 493         497    TCS     EQ  2019-05-13     2135.80     2133.00     2167.00
#
# ...

# %%
data['Date'].dtype
# Out:
# dtype('O')

# %%
data['Date']=data['Date'].astype('datetime64')

# %%
data['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
data=data.set_index(data['Date'])
data.head()
# Out:
#             Unnamed: 0 Symbol Series       Date  Prev Close  Open Price  \
# Date
# 2017-05-15           0    TCS     EQ 2017-05-15     2360.65      2375.1
# 2017-05-16           1    TCS     EQ 2017-05-16     2365.10      2380.0
# 2017-05-17           2    TCS     EQ 2017-05-17     2429.15      2433.5
# 2017-05-18           3    TCS     EQ 2017-05-18     2455.35      2450.0
# 2017-05-19           4    TCS     EQ 2017-05-19     2536.20      2536.2
#
#             High Price  Low Price  Last Price  Close Price  ...  \
# Date                                                        ...
# 2017-05-15     2377.95    2341.60     2368.00      2365.10  ...
# 2017-05-16     2435.00    2373.45     2425.10      2429.15  ...
# 2017-05-17     2460.75    2423.00     2450.00      2455.35  ...
# 2017-05-18     2572.00    2442.25     2525.00      2536.20  ...
# 2017-05-19     2540.55    2486.00     2503.85      2507.15  ...
#
#             Total Traded Quantity      Turnover  No. of Trades  \
# Date
# ...

# %%
plt.figure(figsize=(15,8))
x=data['Date']
y=data['Close Price']
plt.plot(x,y)
plt.xlabel('Date')
plt.ylabel('Closing Price')
# Out:
# Text(0, 0.5, 'Closing Price')

# %%
df=data['Day_Perc_Change'].max()
df
# Out:
# 0.06621437412844887

# %%
dt=data['Day_Perc_Change'].idxmax()
dt
# Out:
# Timestamp('2018-04-20 00:00:00')

# %%
data.loc[data.Date=='2018-04-20 00:00:00']
# Out:
#             Unnamed: 0 Symbol Series       Date  Prev Close  Open Price  \
# Date
# 2018-04-20         233    TCS     EQ 2018-04-20     3191.15      3250.0
#
#             High Price  Low Price  Last Price  Close Price  ...  \
# Date                                                        ...
# 2018-04-20     3422.35     3240.0      3414.0      3402.45  ...
#
#             Total Traded Quantity      Turnover  No. of Trades  \
# Date
# 2018-04-20                9232831  3.093985e+10         287034
#
#             Deliverable Qty  % Dly Qt to Traded Qty  Year  Month         VWAP  \
# Date
# 2018-04-20          2973300                    32.2  2018      4  2756.314556
#
#             Day_Perc_Change        Trend
# Date
# 2018-04-20         0.066214  Top gainers
#
# [1 rows x 21 columns]

# %%
plt.figure(figsize=(15,8))
x=data['Date']
y=data['Day_Perc_Change']
plt.xlabel('Date')
plt.ylabel('Day_Perc_Change')
plt.stem(x,y)
maximum=y.max()
maximum
# Out:
# C:\Users\bhanu\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# 0.06621437412844887

# %%
plt.figure(figsize=(15,8))
plt.stem(data["Date"],data['Total Traded Quantity'])
# Out:
# C:\Users\bhanu\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %%
plt.figure(figsize=(15,8))
plt.stem(data['Day_Perc_Change'],data['Total Traded Quantity'])
# Out:
# C:\Users\bhanu\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %%
plt.figure(figsize=(15,8))
plt.plot(data['Day_Perc_Change'],data['Total Traded Quantity'])

# %% [markdown]
# ### Document of Analysis of relationship between Volume data to the Day_Perc_Change
# In the Above plot we can see the stem plot of volume data and the stem plot of both volume data and Day_Perc_change and we can clearly see that in stem plot of Day_Perc_change drastic change is between the date 2018-04 to 2018-07 while in volume data the change is between 2018-01 to 2018-04. In stem plot more data is between 0-1 only few are more than that. In plot of both 3 points are there which are having more difference only.

# %%
#2.4
pie_data = data.groupby('Trend')
pie_label = sorted([i for i in data.loc[:, 'Trend'].unique()])
plt.pie(pie_data['Trend'].count(), labels = pie_label, 
        autopct = '%1.1f%%', radius = 2)
# Out:
# ([<matplotlib.patches.Wedge at 0x2803a9be888>,
# ...
#  [Text(2.1999555125932337, 0.013990804503086663, 'Bear drop'),
#   Text(1.9414619996568785, 1.034758572754203, 'Negative'),
#   Text(-0.013990897835372476, 2.199955511999677, 'Positive'),
#   Text(-1.8934899016227598, -1.1201321316936819, 'Slight'),
#   Text(1.5995108330322032, -1.5104850528928209, 'Slight positive'),
#   Text(2.114432680092541, -0.6075972690497191, 'Top gainers'),
#   Text(2.1924859084224995, -0.18167427272117498, 'Top losers')],
#  [Text(1.1999757341417636, 0.007631347910774543, '0.2%'),
#   Text(1.0589792725401155, 0.5644137669568379, '15.2%'),
#   Text(-0.007631398819294076, 1.1999757338180055, '19.4%'),
#   Text(-1.0328126736124144, -0.6109811627420082, '47.4%'),
#   Text(0.8724604543812017, -0.8239009379415385, '11.5%'),
#   Text(1.153326916414113, -0.33141669220893766, '3.6%'),
#   Text(1.1959014045940906, -0.09909505784791361, '2.6%')])

# %%
plt.figure(figsize=(15,8))
data.groupby(data['Trend'])['Total Traded Quantity'].mean().plot.bar()

# %%
plt.figure(figsize=(15,8))
data.groupby(data['Trend'])['Total Traded Quantity'].median().plot.bar()

# %%
#2.5
plt.figure(figsize=(15,8))
plt.hist(data['Day_Perc_Change'])
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   0.,   0.,   1., 370., 122.]),
#  array([-0.50455309, -0.44747634, -0.39039959, -0.33332285, -0.2762461 ,
#         -0.21916936, -0.16209261, -0.10501586, -0.04793912,  0.00913763,
#          0.06621437]),
#  <a list of 10 Patch objects>)

# %%
#2.6
mindtree_dt=pd.read_csv('F:\ML Internship Data\module_2\MINDTREE.csv')
pnb_dt=pd.read_csv('F:\ML Internship Data\module_2\PNB.csv')
tatachem_dt=pd.read_csv('F:\ML Internship Data\module_2\TATACHEM.csv')
tatapower_dt=pd.read_csv('F:\ML Internship Data\module_2\TATAPOWER.csv')
voltas_dt=pd.read_csv('F:\ML Internship Data\module_2\VOLTAS.csv')

# %%
mindtree_dt=mindtree_dt[mindtree_dt['Series']=="EQ"]
pnb_dt=pnb_dt[pnb_dt['Series']=="EQ"]
tatachem_dt=tatachem_dt[tatachem_dt['Series']=="EQ"]
tatapower_dt=tatapower_dt[tatapower_dt['Series']=="EQ"]
voltas_dt=voltas_dt[voltas_dt['Series']=="EQ"]

# %%
mindtree_dt=mindtree_dt[['Close Price']]
mindtree_dt.columns=['MindTree']
pnb_dt=pnb_dt[['Close Price']]
pnb_dt.columns=['Pnb']
tatachem_dt=tatachem_dt[['Close Price']]
tatachem_dt.columns=['TataChem']
tatapower_dt=tatapower_dt[['Close Price']]
tatapower_dt.columns=['TataPower']
voltas_dt=voltas_dt[['Close Price']]
voltas_dt.columns=['Voltas']

# %%
Data=pd.concat([mindtree_dt,pnb_dt,tatachem_dt, tatapower_dt, voltas_dt],axis=1)
Data
# Out:
#      MindTree     Pnb  TataChem  TataPower  Voltas
# 0      509.45  166.80    629.80      83.55  431.85
# 1      511.30  174.15    643.90      83.85  432.45
# 2      506.35  165.05    638.10      85.35  430.20
# 3      492.90  158.50    624.90      83.75  414.10
# 4      497.50  155.20    616.45      84.15  415.75
# ..        ...     ...       ...        ...     ...
# 493    979.10   79.80    596.00      63.80  572.20
# 494       NaN     NaN    590.25      62.60     NaN
# 495       NaN     NaN    589.00        NaN     NaN
# 496       NaN     NaN    590.00        NaN     NaN
# 497       NaN     NaN    574.90        NaN     NaN
#
# [498 rows x 5 columns]

# %%
Data_pc=Data.pct_change()*100
Data_pc.dropna(inplace=True, axis=0)

# %%
import seaborn as sns
sns.set_style('whitegrid')
sns.set(font_scale=1.25)
sns.pairplot(Data_pc)

# %%
Voltas_roll=Data_pc['Voltas'].rolling(7).std()*np.sqrt(7)
Voltas_roll.plot(figsize=(15,8))

# %%
#2.8
Nifty=pd.read_csv(r"F:\ML Internship Data\Nifty50.csv")

# %%
N_data=Nifty[['Close']]
N_data.columns=['Nifty']
N_data.head()
# Out:
#      Nifty
# 0  9445.40
# 1  9512.25
# 2  9525.75
# 3  9429.45
# 4  9427.90

# %%
new_data=pd.concat([N_data,pnb_dt,voltas_dt],axis=1)
new_data.pct_change()*100
# Out:
#         Nifty       Pnb    Voltas
# 0         NaN       NaN       NaN
# 1    0.707752  4.406475  0.138937
# 2    0.141922 -5.225380 -0.520291
# 3   -1.010944 -3.968494 -3.742445
# 4   -0.016438 -2.082019  0.398454
# ..        ...       ...       ...
# 489 -0.865217 -2.666667 -0.759013
# 490 -1.204133  0.000000 -4.123369
# 491 -0.507507  0.357356 -0.442209
# 492 -0.202623  2.373887  1.036405
# 493 -1.158801 -7.478261 -1.353332
#
# [494 rows x 3 columns]

# %%
new_data.dropna(inplace=True, axis=0)

# %%
new_data.head()
# Out:
#      Nifty     Pnb  Voltas
# 0  9445.40  166.80  431.85
# 1  9512.25  174.15  432.45
# 2  9525.75  165.05  430.20
# 3  9429.45  158.50  414.10
# 4  9427.90  155.20  415.75

# %%
Volatility=new_data.rolling(7).std()*np.sqrt(7)
Volatility.plot(figsize=(15,8))

# %%
short_window = 21
long_window = 34

signals = pd.DataFrame(index=new_data.index)
signals['signal'] = 0.0

#SMA of Short Window
signals['short_mavg'] = new_data["Voltas"].rolling(window=short_window, min_periods=1,center=False).mean()

#SMA of Long Window
signals['long_mavg'] = new_data['Voltas'].rolling(window=long_window,min_periods=1, center=False).mean()

#Create signals
signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:] > signals['long_mavg'][short_window:], 1.0,0.0)

#Generate trading orders
signals['positions'] = signals['signal'].diff()
signals
# Out:
#      signal  short_mavg   long_mavg  positions
# 0       0.0  431.850000  431.850000        NaN
# 1       0.0  432.150000  432.150000        0.0
# 2       0.0  431.500000  431.500000        0.0
# 3       0.0  427.150000  427.150000        0.0
# 4       0.0  424.870000  424.870000        0.0
# ..      ...         ...         ...        ...
# 489     0.0  611.954762  612.964706        0.0
# 490     0.0  610.047619  612.204412        0.0
# 491     0.0  608.571429  611.442647        0.0
# 492     0.0  607.173810  610.730882        0.0
# 493     0.0  605.271429  609.550000        0.0
#
# [494 rows x 4 columns]

# %%
fig = plt.figure(figsize=(20,15))

#Add a subplot and label for y-axis
ax1 = fig.add_subplot(111, ylabel='Price')

#Plot the closing price
new_data['Voltas'].plot(ax=ax1, color='black', lw=2.)

#plot the short and long moving averages
signals[['short_mavg', 'long_mavg']].plot(ax=ax1, lw=2.)

#Plot the buy signals
ax1.plot(signals.loc[signals.positions == 1.0].index, signals.short_mavg[signals.positions == 1.0], '^' , markersize=20,color='g')

#Plot the sell signals
ax1.plot(signals.loc[signals.positions == -1.0].index, signals.short_mavg[signals.positions == -1.0], 'v' , markersize=20,color='r')

plt.show()

# %%
symbol = 'Pnb'

# read csv file, use date as index and read close as a column
df = pd.read_csv('F:\ML Internship Data\module_2\PNB.csv'.format(symbol), index_col='Date',
                 parse_dates=True, usecols=['Date', 'Close Price'],
                 na_values='nan')

# rename the column header with symbol name
df = df.rename(columns={'Close Price': symbol})
df.dropna(inplace=True)

# calculate Simple Moving Average with 14 days window
sma = df.rolling(window=14).mean()

# calculate the standar deviation
rstd = df.rolling(window=14).std()

upper_band = sma + 2 * rstd
upper_band = upper_band.rename(columns={symbol: 'upper'})
lower_band = sma - 2 * rstd
lower_band = lower_band.rename(columns={symbol: 'lower'})
df = df.join(upper_band).join(lower_band)
ax = df.plot(title='{} Price and BB'.format(symbol))
ax.fill_between(df.index, lower_band['lower'], upper_band['upper'], color='#ADCCFF', alpha='0.4')
ax.set_xlabel('Date')
ax.set_ylabel('SMA and BB')
ax.grid()
plt.show()

# %%
df.to_csv('week2_result.csv')
