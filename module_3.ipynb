# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
import datetime

# %%
df=pd.read_csv(r'F:\ML Internship Data\GOLD.csv')
df
# Out:
#              Date  Price   Open   High    Low    Vol. Change %   Pred  \
# 0    May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  738.0
# 1    May 05, 2017  28184  28136  28382  28135   0.06K    0.44% -146.0
# 2    May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   30.0
# 3    May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  357.0
# 4    May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  124.0
# ..            ...    ...    ...    ...    ...     ...      ...    ...
# 507  Apr 26, 2019  31868  31851  31934  31705   9.67K    0.08%    NaN
# 508  Apr 30, 2019  31625  31800  31824  31597   6.44K   -0.76%    NaN
# 509  May 01, 2019  31563  31604  31657  31503   1.55K   -0.20%    NaN
# 510  May 02, 2019  31203  31420  31425  31160   0.48K   -1.14%    NaN
# 511  May 03, 2019  31341  31250  31500  31163   0.08K    0.44%    NaN
#
#             new
# 0    117.570740
# 1    295.430176
# 2    132.123714
# 3    101.298064
# 4    112.153318
# ..          ...
# ...

# %%
df_new=df.dropna()
df_new.tail()
# Out:
#              Date  Price   Open   High    Low    Vol. Change %   Pred  \
# 406  Dec 04, 2018  30964  30874  31085  30874   0.08K    0.57%  -31.0
# 407  Dec 05, 2018  30926  30830  30970  30825   0.04K   -0.12%   72.0
# 408  Dec 06, 2018  31005  31039  31196  30974  10.55K    0.26%   35.0
# 409  Dec 07, 2018  31440  31011  31480  30941  11.24K    1.40%  669.0
# 410  Dec 10, 2018  31895  31459  31966  31420  14.09K    1.45%  521.0
#
#             new
# 406  301.615081
# 407  241.475101
# 408  188.222186
# 409  976.692705
# 410  990.254297

# %%
x=np.array(df_new['new'])
x
# Out:
# array([ 117.57074041,  295.43017594,  132.12371428,  101.29806419,
#         112.15331832,  182.42708892,  141.25513668,  120.06900986,
#         218.40164139,  919.37635783,  475.3890932 ,  222.89530686,
#         425.73848362,  194.44954767,   69.28900524,   39.22587413,
#         346.15840134,  152.28142465,   63.23430962,  547.11562107,
#          37.21262887,  598.10456764,  201.30676536,  546.56691539,
#         112.39406346,  125.33370177,  110.6119434 ,  132.27451388,
#         161.0781582 ,  280.11492257,   46.40153631,   37.06601399,
#          13.06075193,  115.21287825,  128.55712425,  178.2011992 ,
#         238.33822912,  301.00877441,  243.49371501,  115.16780858,
#         175.88054968,  128.5194192 ,   27.36257833,  300.66286307,
#         243.29340995,   69.1434314 ,   97.8066585 ,  274.12671977,
#         294.38484586,  163.33969109,   40.07141575,  572.8479804 ,
#         220.42534759,  259.59232955,  135.57548845,  351.51838039,
# ...

# %%
y=np.array(df_new['Pred'])
y
# Out:
# array([ 738., -146.,   30.,  357.,  124.,  149.,  167.,   22.,   34.,
#         420.,  234.,  345.,  265.,  138.,  378.,  413.,  214.,  121.,
#         491.,  397.,  404.,  222.,   -3.,  259.,  344.,  906.,  526.,
#         174.,  685.,  329.,  592.,  205.,  292.,  150.,  420.,  -42.,
#         -82.,  262.,   23.,  173.,  550.,  928.,  804.,  -39.,  927.,
#         205.,  771.,  818.,  420.,  142.,  199.,  432.,   71.,  101.,
#         465.,  350.,  322.,  121.,  361.,  436.,  202.,  551.,  224.,
#         486.,  247.,  398.,  316.,  117.,  333.,  364.,  242.,  329.,
#         340.,  804.,  512.,   -4.,  230.,  602.,  129.,  168., 1177.,
#         333.,   73.,  740.,  286.,   12., 1459., 1158.,  258.,  336.,
#         238.,  706.,  339.,  384.,  374.,  471.,  612.,   45.,   83.,
#         548.,   85.,  620.,  754.,  409.,  372.,  483.,  196.,  554.,
#         318.,  359.,   82.,   38.,  147.,   79.,  393.,  -13.,  432.,
# ...

# %%
x.ndim
# Out:
# 1

# %%
y.ndim
# Out:
# 1

# %%
x=x.reshape(-1,1)
y=y.reshape(-1,1)

# %%
reg_model = LinearRegression()
reg_model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predicted = reg_model.predict(x)
rmse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)

# %%
print('Slope:' ,reg_model.coef_)
print('Intercept:', reg_model.intercept_)
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[-0.00823083]]
# Intercept: [343.67028421]
# Root mean squared error:  73300.46132887459
# R2 score:  3.732507600850976e-05

# %%
plt.plot(x, y_predicted, color='g')
plt.show()

# %%
plt.scatter(x, y, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, y_predicted, color='b')
plt.show()

# %%
pre_dt = df[:]
pre_dt_new = pre_dt['new']
pre_dt_new = pre_dt_new.values.reshape(-1,1)
na_data = (reg_model.predict(pre_dt_new))
na_data_series = pd.Series(na_data.ravel())
data = na_data_series.to_frame()
df['Pred'] = data
df
# Out:
#              Date  Price   Open   High    Low    Vol. Change %        Pred  \
# 0    May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  342.702580
# 1    May 05, 2017  28184  28136  28382  28135   0.06K    0.44%  341.238649
# 2    May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%  342.582797
# 3    May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  342.836517
# 4    May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  342.747169
# ..            ...    ...    ...    ...    ...     ...      ...         ...
# 507  Apr 26, 2019  31868  31851  31934  31705   9.67K    0.08%  341.635810
# 508  Apr 30, 2019  31625  31800  31824  31597   6.44K   -0.76%  343.240625
# 509  May 01, 2019  31563  31604  31657  31503   1.55K   -0.20%  342.737786
# 510  May 02, 2019  31203  31420  31425  31160   0.48K   -1.14%  343.272194
# 511  May 03, 2019  31341  31250  31500  31163   0.08K    0.44%  340.131646
#
#             new
# 0    117.570740
# 1    295.430176
# ...

# %%
x=np.array(df['new'])
y=np.array(df['Pred'])

x=x.reshape(-1,1)
y=y.reshape(-1,1)
regression_model=LinearRegression()
regression_model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predicted = reg_model.predict(x)
rmse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)

# %%
print('Slope:' ,regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[-0.00823083]]
# Intercept: [343.67028421]
# Root mean squared error:  0.0
# R2 score:  1.0

# %%
plt.scatter(x, y, s=15)
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, y_predicted, color='g')
plt.show()

# %%
plt.hist(df['Pred'])
plt.show()

# %%
import seaborn as sns
sns.distplot(df['Pred'])

# %%
#3.2
Gail_dt=pd.read_csv("F:\ML Internship Data\Large_Cap\GAIL.csv")
Gail_dt.head()
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   GAIL     EQ  15-May-2017      409.20      413.05      415.25     410.00
# 1   GAIL     EQ  16-May-2017      414.00      415.80      416.00     410.25
# 2   GAIL     EQ  17-May-2017      411.40      411.50      412.90     405.60
# 3   GAIL     EQ  18-May-2017      408.30      406.35      409.00     401.50
# 4   GAIL     EQ  19-May-2017      404.75      404.00      406.35     396.00
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      413.80       414.00         412.83                1077551
# 1      411.00       411.40         412.85                2434834
# 2      408.50       408.30         408.42                2002105
# 3      403.00       404.75         407.03                2132140
# 4      401.35       401.05         400.31                2847835
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
Nifty_dt=pd.read_csv(r"F:\ML Internship Data\Nifty50.csv")
Nifty_dt.head()
# Out:
#           Date     Open     High      Low    Close  Shares Traded  \
# 0  15-May-2017  9433.55  9449.25  9423.10  9445.40      145163953
# 1  16-May-2017  9461.00  9517.20  9456.35  9512.25      171709433
# 2  17-May-2017  9517.60  9532.60  9486.10  9525.75      211856040
# 3  18-May-2017  9453.20  9489.10  9418.10  9429.45      199340647
# 4  19-May-2017  9469.90  9505.75  9390.75  9427.90      259861396
#
#    Turnover (Rs. Cr)
# 0            7790.97
# 1            9209.89
# 2           10726.23
# 3           10782.46
# 4           11544.77

# %%
Gail_dt['Date'] = pd.to_datetime(Gail_dt['Date'])
Gail_dt = Gail_dt.sort_values('Date')
Gail_dt.set_index('Date', inplace=True)
Gail_dt
# Out:
#            Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15   GAIL     EQ      409.20      413.05      415.25     410.00
# 2017-05-16   GAIL     EQ      414.00      415.80      416.00     410.25
# 2017-05-17   GAIL     EQ      411.40      411.50      412.90     405.60
# 2017-05-18   GAIL     EQ      408.30      406.35      409.00     401.50
# 2017-05-19   GAIL     EQ      404.75      404.00      406.35     396.00
# ...           ...    ...         ...         ...         ...        ...
# 2019-05-07   GAIL     EQ      346.25      348.00      356.95     339.65
# 2019-05-08   GAIL     EQ      340.75      341.00      345.15     336.40
# 2019-05-09   GAIL     EQ      337.50      337.10      341.45     333.05
# 2019-05-10   GAIL     EQ      340.40      341.00      343.80     338.20
# 2019-05-13   GAIL     EQ      341.55      341.55      342.80     330.30
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# ...

# %%
Nifty_dt['Date'] = pd.to_datetime(Nifty_dt['Date'])
Nifty_dt = Nifty_dt.sort_values('Date')
Nifty_dt.set_index('Date', inplace=True)
Nifty_dt
# Out:
#                 Open      High       Low     Close  Shares Traded  \
# Date
# 2017-05-15   9433.55   9449.25   9423.10   9445.40      145163953
# 2017-05-16   9461.00   9517.20   9456.35   9512.25      171709433
# 2017-05-17   9517.60   9532.60   9486.10   9525.75      211856040
# 2017-05-18   9453.20   9489.10   9418.10   9429.45      199340647
# 2017-05-19   9469.90   9505.75   9390.75   9427.90      259861396
# ...              ...       ...       ...       ...            ...
# 2019-05-07  11651.50  11657.05  11484.45  11497.90      337495624
# 2019-05-08  11478.70  11479.10  11346.95  11359.45      372826025
# 2019-05-09  11322.40  11357.60  11255.05  11301.80      373028059
# 2019-05-10  11314.15  11345.80  11251.05  11278.90      387323416
# 2019-05-13  11258.70  11300.20  11125.60  11148.20      357586433
#
#             Turnover (Rs. Cr)
# Date
# 2017-05-15            7790.97
# 2017-05-16            9209.89
# 2017-05-17           10726.23
# 2017-05-18           10782.46
# ...

# %%
Gail=Gail_dt.tail(90)
Gail
# Out:
#            Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2018-12-31   GAIL     EQ      356.30      357.60      361.80     354.00
# 2019-01-01   GAIL     EQ      360.30      359.00      364.00     356.95
# 2019-01-02   GAIL     EQ      362.15      360.55      361.90     347.55
# 2019-01-03   GAIL     EQ      350.30      350.30      352.45     346.95
# 2019-01-04   GAIL     EQ      349.95      350.25      353.90     347.55
# ...           ...    ...         ...         ...         ...        ...
# 2019-05-07   GAIL     EQ      346.25      348.00      356.95     339.65
# 2019-05-08   GAIL     EQ      340.75      341.00      345.15     336.40
# 2019-05-09   GAIL     EQ      337.50      337.10      341.45     333.05
# 2019-05-10   GAIL     EQ      340.40      341.00      343.80     338.20
# 2019-05-13   GAIL     EQ      341.55      341.55      342.80     330.30
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# ...

# %%
Nifty=Nifty_dt.tail(90)
Nifty
# Out:
#                 Open      High       Low     Close  Shares Traded  \
# Date
# 2018-12-31  10913.20  10923.55  10853.20  10862.55      186494657
# 2019-01-01  10881.70  10923.60  10807.10  10910.10      159404542
# 2019-01-02  10868.85  10895.35  10735.05  10792.50      309665939
# 2019-01-03  10796.80  10814.05  10661.25  10672.25      286241745
# 2019-01-04  10699.70  10741.05  10628.65  10727.35      296596655
# ...              ...       ...       ...       ...            ...
# 2019-05-07  11651.50  11657.05  11484.45  11497.90      337495624
# 2019-05-08  11478.70  11479.10  11346.95  11359.45      372826025
# 2019-05-09  11322.40  11357.60  11255.05  11301.80      373028059
# 2019-05-10  11314.15  11345.80  11251.05  11278.90      387323416
# 2019-05-13  11258.70  11300.20  11125.60  11148.20      357586433
#
#             Turnover (Rs. Cr)
# Date
# 2018-12-31           10176.13
# 2019-01-01            8688.26
# 2019-01-02           15352.25
# 2019-01-03           15030.45
# ...

# %%
Gail_new=Gail['Close Price'].pct_change()
Nifty_new=Nifty['Close'].pct_change()
plt.figure(figsize=(15,8))
Gail_new.plot()
Nifty_new.plot()
plt.ylabel("Daily Return of Gail and NIFTY")
plt.show()

# %%
Gail['pct_change']=Gail_new
Gail
# Out:
# C:\Users\bhanu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2018-12-31   GAIL     EQ      356.30      357.60      361.80     354.00
# 2019-01-01   GAIL     EQ      360.30      359.00      364.00     356.95
# 2019-01-02   GAIL     EQ      362.15      360.55      361.90     347.55
# 2019-01-03   GAIL     EQ      350.30      350.30      352.45     346.95
# 2019-01-04   GAIL     EQ      349.95      350.25      353.90     347.55
# ...           ...    ...         ...         ...         ...        ...
# ...

# %%
Nifty['pct_change']=Nifty_new
Nifty
# Out:
# C:\Users\bhanu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 Open      High       Low     Close  Shares Traded  \
# Date
# 2018-12-31  10913.20  10923.55  10853.20  10862.55      186494657
# 2019-01-01  10881.70  10923.60  10807.10  10910.10      159404542
# 2019-01-02  10868.85  10895.35  10735.05  10792.50      309665939
# 2019-01-03  10796.80  10814.05  10661.25  10672.25      286241745
# 2019-01-04  10699.70  10741.05  10628.65  10727.35      296596655
# ...              ...       ...       ...       ...            ...
# 2019-05-07  11651.50  11657.05  11484.45  11497.90      337495624
# ...

# %%
x = Nifty['pct_change'].dropna()
y = Gail['pct_change'].dropna()

# %%
myModel = sm.OLS(x,y).fit()
myModel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             pct_change   R-squared (uncentered):                   0.224
# Model:                            OLS   Adj. R-squared (uncentered):              0.215
# Method:                 Least Squares   F-statistic:                              25.43
# Date:                Thu, 28 May 2020   Prob (F-statistic):                    2.43e-06
# Time:                        14:50:50   Log-Likelihood:                          328.25
# No. Observations:                  89   AIC:                                     -654.5
# Df Residuals:                      88   BIC:                                     -652.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
new_data=pd.concat([Gail_dt["Close Price"], Nifty_dt["Close"]], axis=1 )
new_data=new_data.pct_change(1)
new_data.dropna(inplace=True)
new_data
# Out:
#             Close Price     Close
# Date
# 2017-05-16    -0.006280  0.007078
# 2017-05-17    -0.007535  0.001419
# 2017-05-18    -0.008695 -0.010109
# 2017-05-19    -0.009141 -0.000164
# 2017-05-22    -0.027054  0.001098
# ...                 ...       ...
# 2019-05-07    -0.015884 -0.008652
# 2019-05-08    -0.009538 -0.012041
# 2019-05-09     0.008593 -0.005075
# 2019-05-10     0.003378 -0.002026
# 2019-05-13    -0.027814 -0.011588
#
# [493 rows x 2 columns]

# %%
x=new_data['Close Price'].resample('M').sum()
x
# Out:
# Date
# 2017-05-31    0.001809
# 2017-06-30   -0.133506
# 2017-07-31    0.043601
# 2017-08-31    0.006441
# 2017-09-30    0.107603
# 2017-10-31    0.108110
# 2017-11-30    0.008690
# 2017-12-31    0.069344
# 2018-01-31   -0.039706
# 2018-02-28   -0.043023
# 2018-03-31   -0.292876
# 2018-04-30   -0.008829
# 2018-05-31    0.081795
# 2018-06-30   -0.026414
# 2018-07-31    0.099761
# 2018-08-31   -0.002864
# 2018-09-30    0.020465
# 2018-10-31   -0.002497
# 2018-11-30   -0.084404
# 2018-12-31    0.052187
# 2019-01-31   -0.076974
# 2019-02-28    0.032173
# 2019-03-31    0.017922
# 2019-04-30    0.026975
# 2019-05-31   -0.068591
# Freq: M, Name: Close Price, dtype: float64

# %%
y=new_data['Close'].resample('M').sum()
y
# Out:
# Date
# 2017-05-31    0.018712
# 2017-06-30   -0.010363
# 2017-07-31    0.057063
# 2017-08-31   -0.015394
# 2017-09-30   -0.012715
# 2017-10-31    0.054643
# 2017-11-30   -0.010216
# 2017-12-31    0.029696
# 2018-01-31    0.046422
# 2018-02-28   -0.048928
# 2018-03-31   -0.036035
# 2018-04-30    0.060431
# 2018-05-31    0.000135
# 2018-06-30   -0.001670
# 2018-07-31    0.058512
# 2018-08-31    0.028445
# 2018-09-30   -0.065655
# 2018-10-31   -0.048814
# 2018-11-30    0.046653
# 2018-12-31   -0.000413
# 2019-01-31   -0.002349
# 2019-02-28   -0.003187
# 2019-03-31    0.074713
# 2019-04-30    0.011053
# 2019-05-31   -0.052174
# Freq: M, Name: Close, dtype: float64

# %%
x1 = sm.add_constant(x)
model = sm.OLS(y, x1)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Close   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     2.866
# Date:                Thu, 28 May 2020   Prob (F-statistic):              0.104
# Time:                        14:52:04   Log-Likelihood:                 47.155
# No. Observations:                  25   AIC:                            -90.31
# Df Residuals:                      23   BIC:                            -87.87
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0078      0.008      1.015      0.321      -0.008       0.024
# ...

# %% [markdown]
# ### Daily beta value for the past 3 months for the stock
# ### GAIL is 0.1896 which is less than 1 and hence it is less volatile than the benchmark

# %% [markdown]
# ### The monthly beta value for the stock GAIL is 0.1539
# ### which is less than 1 and hence it is less volatile than the benchmark
